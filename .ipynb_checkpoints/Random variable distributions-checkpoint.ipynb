# %%
import pandas as pd

# %%
numerical = pd.read_csv('numerical_df.csv')

# %%
numerical = numerical.drop(['clt_categories'], axis=1)
numerical
# Out:
# KeyboardInterrupt

# %%
numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
import seaborn as sns

# %% [markdown]
# ## Income

# %%
sns.histplot(numerical.final_income)
# Out:
# <Axes: xlabel='final_income', ylabel='Count'>

# %%
# with our predicted model to filled the 0 income, we don't have outliers
# But skewed a bit to the left

# %% [markdown]
# ## monthly_premium_auto

# %%
sns.histplot(numerical.monthly_premium_auto, bins=15)
# Out:
# <Axes: xlabel='monthly_premium_auto', ylabel='Count'>

# %%
# outliers : just a few value > 150

# %%
import numpy as np

# %%
transformed_MPA = np.log(numerical.monthly_premium_auto)
sns.histplot(transformed_MPA, bins=10)
# Out:
# <Axes: xlabel='monthly_premium_auto', ylabel='Count'>

# %%
# Still outliers, but we can better see them

# %%
sns.histplot(numerical.customer_lifetime_value, bins=15)
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Count'>

# %%
# outliers : just a few value > 40000
# the graph is exponential distribution

# %%
transformed_clv = np.log(numerical.customer_lifetime_value)
sns.histplot(transformed_clv, bins=10)
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Count'>

# %%
# this gave us a normal distribution => OK

# %% [markdown]
# ## total_claim_amount

# %%
sns.histplot(numerical.total_claim_amount, bins=15)
# Out:
# <Axes: xlabel='total_claim_amount', ylabel='Count'>

# %%
# Outliers to the right

# %%
transformed_tca = np.log(numerical.total_claim_amount)
sns.histplot(transformed_tca, bins=15)
# Out:
# <Axes: xlabel='total_claim_amount', ylabel='Count'>

# %%
# looks better but it is skewed a bit to the right

# %% [markdown]
# ## Power Transformer

# %%
from sklearn.preprocessing import power_transform

from sklearn.preprocessing import PowerTransformer

power_transform(numerical, method='yeo-johnson')
sns.histplot(power_transform(numerical, method='yeo-johnson'))
# Out:
# <Axes: ylabel='Count'>

# %%
## I don't know how to make this graph readable.
# I tried couple of things which did not work

# %%
## Wait for the lab review.

# %%
## I did not understand much what I am doing here
